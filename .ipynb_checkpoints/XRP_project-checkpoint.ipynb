# %% [markdown]
# # importing required library

# %%
import os
import glob
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(font_scale=2)
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
root_dir = os.getcwd()
root_dir
# Out:
# 'G:\\first_project_shivan'

# %%
## Reading all the csv data
os.listdir(root_dir)
data_path = os.path.join(root_dir,'data')
data_path
# Out:
# 'G:\\first_project_shivan\\data'

# %% [markdown]
# ## 1.  Combining the files to create a single csv

# %%
csvfile_paths = glob.glob(data_path + "/*.csv")
df = pd.DataFrame()
for path in csvfile_paths:
    temp_df = pd.read_csv(path,header=None)
    print(f"path:{path} , shape:{temp_df.shape}")
    df = pd.concat([df,temp_df],ignore_index=True)
print("===============================")
print(f"combine data: {df.shape}")   
df.to_csv("2023_XRP_data.csv",index=False)
# Out:
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-01.csv , shape:(31, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-02.csv , shape:(28, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-03.csv , shape:(31, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-04.csv , shape:(30, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-05.csv , shape:(31, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-06.csv , shape:(30, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-07.csv , shape:(31, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-08.csv , shape:(31, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-09.csv , shape:(30, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-10.csv , shape:(31, 12)
# path:G:\first_project_shivan\data\XRPUSDT-1d-2023-11.csv , shape:(30, 12)
# ...
# combine data: (334, 12)

# %%
df
# Out:
#                 0       1       2       3       4            5   \
# 0    1672531200000  0.3389  0.3400  0.3354  0.3387  102026821.0
# 1    1672617600000  0.3386  0.3555  0.3000  0.3482  647520487.0
# 2    1672704000000  0.3482  0.3520  0.3395  0.3436  346410334.0
# 3    1672790400000  0.3436  0.3605  0.3390  0.3472  372672796.0
# 4    1672876800000  0.3471  0.3487  0.3333  0.3380  265529668.0
# ..             ...     ...     ...     ...     ...          ...
# 329  1700956800000  0.6228  0.6375  0.6064  0.6157  266307412.0
# 330  1701043200000  0.6157  0.6168  0.5937  0.6039  309411406.0
# 331  1701129600000  0.6039  0.6139  0.5957  0.6107  286127938.0
# 332  1701216000000  0.6106  0.6170  0.6040  0.6091  235341461.0
# 333  1701302400000  0.6090  0.6099  0.5982  0.6063  232714430.0
#
#                 6             7       8            9             10  11
# 0    1672617599999  3.447164e+07   48661   53592277.0  1.810790e+07   0
# ...

# %% [markdown]
# ## 2. Importing final dataset file

# %%
final_df = pd.read_csv("2023_XRP_data.csv")
final_df
# Out:
#                  0       1       2       3       4            5  \
# 0    1672531200000  0.3389  0.3400  0.3354  0.3387  102026821.0
# 1    1672617600000  0.3386  0.3555  0.3000  0.3482  647520487.0
# 2    1672704000000  0.3482  0.3520  0.3395  0.3436  346410334.0
# 3    1672790400000  0.3436  0.3605  0.3390  0.3472  372672796.0
# 4    1672876800000  0.3471  0.3487  0.3333  0.3380  265529668.0
# ..             ...     ...     ...     ...     ...          ...
# 329  1700956800000  0.6228  0.6375  0.6064  0.6157  266307412.0
# 330  1701043200000  0.6157  0.6168  0.5937  0.6039  309411406.0
# 331  1701129600000  0.6039  0.6139  0.5957  0.6107  286127938.0
# 332  1701216000000  0.6106  0.6170  0.6040  0.6091  235341461.0
# 333  1701302400000  0.6090  0.6099  0.5982  0.6063  232714430.0
#
#                  6             7       8            9            10  11
# 0    1672617599999  3.447164e+07   48661   53592277.0  1.810790e+07   0
# ...

# %% [markdown]
# ## 3&4. This parameters/features from  SPOT -> Klines  git repo provided in question

# %%
columns = ["Open time",
           "Open",
           "High",
           "Low",
           "Close",
           "Volume",
           "Close time",
           "Quote asset volume",
           "Number of trades",
           "Taker buy base asset volume",
           "Taker buy quote asset volume",
           "Ignore"]
final_df.columns = columns

# %% [markdown]
# # 1. **open_time:**Kline Open time in unix time format
# # 2. **open:**Open Price
# # 3. **high:**High Price
# # 4. **low:**Low Price
# # 5. **close:**Close Price
# # 6. **volume:**Volume
# # 7. **close_time:**Kline Close time in unix time format
# # 8. **quote_volume:**Quote Asset Volume
# # 9. **count:**Number of Trades
# # 10. **taker_buy_volume:**Taker buy base asset volume during this period
# # 11. **taker_buy_quote_volume:**Taker buy quote asset volume during this period
# # 12. **ignore:**Ignore

# %% [markdown]
# ## ==========================================================================

# %% [markdown]
# # Question-5

# %%
final_df
# Out:
#          Open time    Open    High     Low   Close       Volume  \
# 0    1672531200000  0.3389  0.3400  0.3354  0.3387  102026821.0
# 1    1672617600000  0.3386  0.3555  0.3000  0.3482  647520487.0
# 2    1672704000000  0.3482  0.3520  0.3395  0.3436  346410334.0
# 3    1672790400000  0.3436  0.3605  0.3390  0.3472  372672796.0
# 4    1672876800000  0.3471  0.3487  0.3333  0.3380  265529668.0
# ..             ...     ...     ...     ...     ...          ...
# 329  1700956800000  0.6228  0.6375  0.6064  0.6157  266307412.0
# 330  1701043200000  0.6157  0.6168  0.5937  0.6039  309411406.0
# 331  1701129600000  0.6039  0.6139  0.5957  0.6107  286127938.0
# 332  1701216000000  0.6106  0.6170  0.6040  0.6091  235341461.0
# 333  1701302400000  0.6090  0.6099  0.5982  0.6063  232714430.0
#
#         Close time  Quote asset volume  Number of trades  \
# 0    1672617599999        3.447164e+07             48661
# 1    1672703999999        2.178040e+08            285660
# ...

# %%
final_df.isnull().sum()
# Out:
# Open time                       0
# Open                            0
# High                            0
# Low                             0
# Close                           0
# Volume                          0
# Close time                      0
# Quote asset volume              0
# Number of trades                0
# Taker buy base asset volume     0
# Taker buy quote asset volume    0
# Ignore                          0
# dtype: int64

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Open time                     334 non-null    int64
#  1   Open                          334 non-null    float64
#  2   High                          334 non-null    float64
#  3   Low                           334 non-null    float64
#  4   Close                         334 non-null    float64
#  5   Volume                        334 non-null    float64
#  6   Close time                    334 non-null    int64
#  7   Quote asset volume            334 non-null    float64
#  8   Number of trades              334 non-null    int64
#  9   Taker buy base asset volume   334 non-null    float64
#  10  Taker buy quote asset volume  334 non-null    float64
#  11  Ignore                        334 non-null    int64
# dtypes: float64(8), int64(4)
# ...

# %%
final_df.drop_duplicates(inplace=True)

# %%
final_df
# Out:
#          Open time    Open    High     Low   Close       Volume  \
# 0    1672531200000  0.3389  0.3400  0.3354  0.3387  102026821.0
# 1    1672617600000  0.3386  0.3555  0.3000  0.3482  647520487.0
# 2    1672704000000  0.3482  0.3520  0.3395  0.3436  346410334.0
# 3    1672790400000  0.3436  0.3605  0.3390  0.3472  372672796.0
# 4    1672876800000  0.3471  0.3487  0.3333  0.3380  265529668.0
# ..             ...     ...     ...     ...     ...          ...
# 329  1700956800000  0.6228  0.6375  0.6064  0.6157  266307412.0
# 330  1701043200000  0.6157  0.6168  0.5937  0.6039  309411406.0
# 331  1701129600000  0.6039  0.6139  0.5957  0.6107  286127938.0
# 332  1701216000000  0.6106  0.6170  0.6040  0.6091  235341461.0
# 333  1701302400000  0.6090  0.6099  0.5982  0.6063  232714430.0
#
#         Close time  Quote asset volume  Number of trades  \
# 0    1672617599999        3.447164e+07             48661
# 1    1672703999999        2.178040e+08            285660
# ...

# %% [markdown]
# ## 1. There is no duplicate value present in the dataset.
# ## 1. There is no null value present in datset.
# ## 2. There is no missing value present in dataset.

# %% [markdown]
# # Question-6

# %%
final_df.describe().T
# Out:
#                               count          mean           std           min  \
# Open time                     334.0  1.686917e+12  8.342933e+09  1.672531e+12
# Open                          334.0  5.008153e-01  9.962790e-02  3.380000e-01
# High                          334.0  5.139027e-01  1.054209e-01  3.400000e-01
# Low                           334.0  4.866868e-01  9.443174e-02  3.000000e-01
# Close                         334.0  5.016213e-01  9.940615e-02  3.380000e-01
# Volume                        334.0  3.687655e+08  2.409843e+08  6.313711e+07
# Close time                    334.0  1.687003e+12  8.342933e+09  1.672618e+12
# Quote asset volume            334.0  1.885232e+08  1.528390e+08  3.298534e+07
# Number of trades              334.0  2.217749e+05  2.182125e+05  3.836700e+04
# Taker buy base asset volume   334.0  1.861700e+08  1.208037e+08  2.745739e+07
# Taker buy quote asset volume  334.0  9.505041e+07  7.652807e+07  1.434515e+07
# ...

# %% [markdown]
# # showing distribution for each column

# %%
for clm in columns:
    fig, ax = plt.subplots(figsize=(20, 5))
    sns.distplot(a=final_df[clm], color='green',hist_kws={"edgecolor": 'black'})
    plt.show()
